# %% [markdown]
# ## Importação das Libs
# import cv2
# import matplotlib.pyplot as plt

# %% [markdown]
# ### Instalador Python
# !pip install opencv-python

# %% [markdown]
# ### Carrega imagem do carro
# img = cv2.imread("carro.jpg")

# %% [markdown]
# ### Converte padrões de cor
# img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ### Insere a imagem na forma
# img.shape

# %% [markdown]
# ### Mostra a imagem
# plt.imshow(img)
# plt.show()

# %%
# !pip install opencv-python
 
import cv2
import matplotlib.pyplot as plt
 
img = cv2.imread("carro.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
 
img.shape
 
plt.imshow(img)
plt.show()
# Out:
# Requirement already satisfied: opencv-python in c:\users\famema 3151\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\famema 3151\anaconda3\lib\site-packages (from opencv-python) (1.21.5)
